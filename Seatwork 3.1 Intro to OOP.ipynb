# %% [markdown]
# #Student Name: Joaz Ephraim A. Flores

# %%
"""
    Accounts.py
"""

class Accounts(): # create the class
    def __init__(self, account_number, account_firstname, account_lastname, current_balance, address, email):
        self.account_number = account_number
        self.account_firstname = account_firstname
        self.account_lastname = account_lastname
        self.current_balance = current_balance
        self.address = address
        self.email = email

    def update_address(self, new_address):
        self.address = new_address

    def update_email(self, new_email):
        self.email = new_email

# %%
"""
    ATM.py
"""

class ATM():
    def __init__(self, serial_number):
        self.serial_number = serial_number        
    
    def deposit(self, account, amount):
        self.account.current_balance = account.current_balance + amount
        print("Deposit Complete")

    def widthdraw(self, account, amount):
        self.account.current_balance = account.current_balance - amount
        print("Widthdraw Complete")

    def check_currentbalance(self, account):
        self.account.current_balance = account.current_balance
        print(account.current_balance)


    def view_transactionsummary(self):
        # Display the transaction summary
        print("Transaction Summary:")
        for transaction in self.transactions:
            print(transaction)
        # Log transactions to a text file    
        with open("transaction_log.txt", "w") as file:
            for transaction in self.transactions:
                file.write(transaction + "\n")
        print("Transaction summary saved to transaction_log.txt")

# %%
"""
    main.py
"""
import Accounts
import ATM

Account1 = Accounts.Accounts(account_number = 123456, account_firstname = "Royce",
                             account_lastname = "Chua", current_balance = 1000,
                             address = "Silver Street Quezon City", 
                             email = "roycechua123@gmail.com") # create the instance/object

#Account1 = Accounts.Accounts() "Causes Error"
Account1.account_firstname = "Royce"
Account1.account_lastname = "Chua"
Account1.current_balance = 1000
Account1.address = "Silver Street Quezon City"
Account1.email = "roycechua123@gmail.com"

print("Account1")
print(Account1.account_firstname)
print(Account1.account_lastname)
print(Account1.current_balance)
print(Account1.address)
print(Account1.email)

print()

Account2 = Accounts.Accounts(account_number = 654321, account_firstname = "John",
                             account_lastname = "Doe", current_balance = 2000,
                             address = "Gold Street Quezon City",
                             email = "johndoe@yahoo.com")

#Account2 = Accounts.Accounts() "Causes Error"
Account2.account_firstname = "John"
Account2.account_lastnamae = "Doe"
Account2.current_balance = 2000
Account2.address = "Gold Street Quezon City"
Account2.email = "johndoe@yahoo.com"

print("Account2")
print(Account2.account_firstname)
print(Account2.account_lastnamae)
print(Account2.current_balance)
print(Account2.address)
print(Account2.email)

# Creating and Using an ATM object
ATM1 = ATM.ATM(serial_number = 987654) #Running into issue ATM() takes no arguments
ATM1.deposit(Account1, 500)
ATM1.check_currentbalance(Account1)

ATM1.deposit(Account2, 300)
ATM1.check_currentbalance(Account2)

print(f"ATM Serial Number: {ATM1.serial_number}")

ATM1.view_transactionsummary() #Code not working
# Out:
# Account1
# Royce
# Chua
# 1000
# Silver Street Quezon City
# roycechua123@gmail.com
#
# Account2
# John
# Doe
# 2000
# Gold Street Quezon City
# johndoe@yahoo.com
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 48
#      45 print(Account2.email)
#      47 # Creating and Using an ATM object
# ---> 48 ATM1 = ATM.ATM(serial_number = 987654)
#      49 ATM1.deposit(Account1, 500)
#      50 ATM1.check_currentbalance(Account1)
#
# TypeError: ATM() takes no arguments

# %%
"""
6. Supplementary Activity:

Tasks
1. Modify the ATM.py program and add the constructor function.
2. Modify the main.py program and initialize the ATM machine with any integer serial number combination and display
the serial number at the end of the program.
3. Modify the ATM.py program and add the view_transactionsummary() method. The method should display all the
transaction made in the ATM object and log it to a text file.

Questions
1. What is a class in Object-Oriented Programming?

A class is like a templplate for creating objects in OOP.

2. Why do you think classes are being implemented in certain programs while some are sequential(line-by-line)?

Classes are better suited for more complex programs since it makes the code more modular and since some programs are worked on by multiple programmers 
having classes makes it easier for other people to modify or troubleshoot parts of a complex program.

3. How is it that there are variables of the same name such account_firstname and account_lastname that exist but
have different values?

Having classes within a code helps in defining variables which are otherwise having the same name since classes can store different data.

4. Explain the constructor functions role in initializing the attributes of the class? When does the Constructor function
execute or when is the constructor function called?

A constructor function is called in python using the __init__ command. With the __init__ line the constructor will be initilized
when it's function is called.

5. Explain the benefits of using Constructors over initializing the variables one by one in the main program?

It makes codes more effiecient and cleaner compared to initializing variables one by one.

7. Conclusion:

As we get further into the uses of python we are slowly being introducted to much more advanced methods of making the codes
more efficient and cleaner like using constructors. Since the more complicated programs are usually made up of different compontents
each comprising a lot of functions within them. And since most programs are maintained by several programmers it really helps
make the codes more modular so development and troubleshooting becomes easier and more effecient for everyone.
"""
